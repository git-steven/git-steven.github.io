# %% [markdown]
# ## Setup & start Spark NLP

# %%
import pyspark.sql.functions as F
import sparknlp
from sparknlp.annotator import *
from sparknlp.common import *
from sparknlp.base import *

from IPython.display import display, HTML

# spark = SparkSession.builder.master("spark://localhost:7077").appName("HarryPotterAnalysis").getOrCreate()
# spark.catalog.clearCache()

def display_df(df, rows=1):
    display(HTML(df.toPandas().head(rows).to_html()))

spark = sparknlp.start()
# Out:
# Warning::Spark Session already created, some configs may not take.

# %% [markdown]
# ## Load some data

# %%
data = spark.read.csv("hp_script.csv", header=True, inferSchema=True)
print("data rows:", data.count())
DIALOGUE_COLUMN = 'dialogue'
data.describe()
# Out:
# data rows: 793
# DataFrame[summary: string, ID_number: string, scene: string, character_name: string, sentence: string]

# %%
# from sparknlp.pretrained import PretrainedPipeline
# # Define a pipeline
# pipeline = PretrainedPipeline('recognize_entities_dl', lang='en')
# ppres = pipeline.fullAnnotate(data)

# %% [markdown]
# ## Create pipeline
# * DocumentAssembler
# * Tokenizer
# * BERT classifier
# * NER converter

# %%
document_assembler = DocumentAssembler().setInputCol(DIALOGUE_COLUMN).setOutputCol("document")


tokenizer = Tokenizer().setInputCols(["document"]).setOutputCol("token")
# bert_base_token_classifier_conll03
ner_model = BertForTokenClassification \
    .pretrained("bert_token_classifier_base_token_classification_for_atc_english_uwb_atcc", "en") \
    .setInputCols(["document", "token"]) \
    .setOutputCol("ner")


ner_converter = NerConverter() \
    .setInputCols(["document", "token", "ner"]) \
    .setOutputCol("ner_span")

pipeline = Pipeline(stages=[ document_assembler, 
                                 tokenizer,
                                 ner_model,
                                 ner_converter
                                 ])
# Out:
# bert_token_classifier_base_token_classification_for_atc_english_uwb_atcc download started this may take some time.
# Approximate size to download 388.3 MB
# [OK!]

# %%
import pyspark.sql.functions as F


# def dialogue_generator():
#     for row in data.toLocalIterator():
#       yield(row["sentence"])

# dialogue = " ".join(list(dialogue_generator()))

# Create the dataframe
df_empty = spark.createDataFrame([['']]).toDF("text")#spark.createDataFrame([['']], ['Sentence']) #.toDF("text")
df_all = data.agg(F.array_join(F.collect_list("sentence"), ' ', ' ').alias(DIALOGUE_COLUMN))
dialogue = df_all.first()[DIALOGUE_COLUMN]

# Fit the dataframe to the pipeline to get the model
model = pipeline.fit(df_all)

# Convert to LightPipeline Model
light_model = LightPipeline(model)

# Full annotate the light model to get predictions
cpres = light_model.fullAnnotate(dialogue)
# Out:
# 49752

# %%
cpres[0:10]
# from sparknlp_display import NerVisualizer
# visualiser = NerVisualizer()

# visualiser.display(cpres, label_col='entities', document_col='document', save_path=f"display_result_ner.html")
# Out:
# [{'document': [Annotation(document, 0, 49751, I should have known that you would be here, Professor McGonagall. Good evening, Professor Dumbledore. Are the rumours true Albus? I'm afraid so, Professor. The good, and the bad. And the boy? Hagrid is bringing him. Do you think it wise to trust Hagrid with something as important as this? Ah, Professor, I would trust Hagrid with my life. Professor Dumbledore, Sir. Professor McGonagall. No problems, I trust, Hagrid? No, Sir. Little tyke fell asleep just as we were flying over Bristol. Heh.Try not to wake him. There you go. Albus, do you really think it's safe, leaving him with these people? I've watched them all day. They're the worst sort of Muggles imaginable. They really are The only family he has. This boy will be famous. There won't be a child in our world who doesn't know his name. Exactly. He's far better off growing up away from all of that. Until he is ready. There there, Hagrid. It's not really goodbye, after all. Good luck, Harry Potter. Up. Get up. Now! Wake up, cousin! We're going to the zoo! Oh, here he comes, the birthday boy! Happy birthday, son. Why don't you just cook the breakfast, and try not to burn anything. Yes, Aunt Petunia. I want everything to be perfect for my Dudley's special day. Hurry up! Bring my coffee, boy! Yes, Uncle Vernon. Aren't they wonderful, darling? How many are there? Thirty-six. Counted them myself. Thirty-six?! But last year, last year I had thirty-seven! Err yes, well, some of them are quite a bit bigger than last year. I don't care how big they are! Oh, now, now, now. This is what we're going to do, is that when we go out, we're going to buy you two new presents! How's that, pumpkin? This will be a lovely day at the zoo. I'm really looking forward to it. I'm warning you now, boy. Any funny business, any at all, and you won't have any meals for a week. Get in. Make it move. Move! MOVE! He's asleep! He's boring. Sorry about him. He doesn't understand what it's like, lying there day after day, having people press their ugly faces in on you. Can you hear me? It's just I've never talked to a snake before. Do you I mean do you talk to people often? You're from Burma, aren't you? Was it nice there, do you miss your family? I see. That's me as well. I never knew my parents, either. Mummy, dad, come here! You won't believe what this snake is doing! Whoa! Ahh! Ahh!! Thanks. Any time. Mum, mummy! AHH! Mum, help! Help me! My darling boy! How did you get in there?! How did you get in there? Dursley, oh, Dursley! It's all right, sweetheart. It's all right. Ow! What happened?! I swear I don't know! One minute, the glass was there and then it was gone! It was like magic! There's no such thing as magic! Oh, Marge is ill! Ate a funny whelk. Dad! Look! Harry's got a letter! Hey, give it back! It's mine! Yours? Who'd be writing to you? No more mail through this letterbox. Have a lovely day at the office, dear. Shoo! Go on! Fine day Sunday. In my opinion, best day of the week. Why is that, Dudley? Because there's no post on Sunday? Ah, right you are, Harry. No post on Sunday. Ha! No blasted letters today. No, sir. Not one single letter, not one. No, sir, not one blasted, miserable- AHH! Make it stop! Please make it stop!  Go away, ahh! What is it? Please tell me what is happening! Give me that! Give me that letter! Get off! Ahh! Ahh! They're my letters! Let go of me! That's it! We're going away! Far away! Where they can't find us! Daddy's gone mad, hasn't he?! Make a wish, Harry. Who's there? Ahh! Sorry 'bout that. I demand that you leave at once, sir! You are breaking and entering! Dry up, Dursley, you great prune.  Boy, I haven't seen you since you was a baby, Harry, but you're a bit more along than I would have expected. Particularly 'round the middle! I-I-I'm not Harry. I-I am. Oh, well, of course you are! Got something for ya. 'Fraid I might have sat on it at some point! I imagine that it'll taste just the same. Ahh. Baked it myself. Words and all. Heh. ...
#   'token': [Annotation(token, 0, 0, I, {'sentence': '0'}, []),
#    Annotation(token, 2, 7, should, {'sentence': '0'}, []),
#    Annotation(token, 9, 12, have, {'sentence': '0'}, []),
#    Annotation(token, 14, 18, known, {'sentence': '0'}, []),
#    Annotation(token, 20, 23, that, {'sentence': '0'}, []),
#    Annotation(token, 25, 27, you, {'sentence': '0'}, []),
#    Annotation(token, 29, 33, would, {'sentence': '0'}, []),
#    Annotation(token, 35, 36, be, {'sentence': '0'}, []),
#    Annotation(token, 38, 41, here, {'sentence': '0'}, []),
#    Annotation(token, 42, 42, ,, {'sentence': '0'}, []),
#    Annotation(token, 44, 52, Professor, {'sentence': '0'}, []),
#    Annotation(token, 54, 63, McGonagall, {'sentence': '0'}, []),
#    Annotation(token, 64, 64, ., {'sentence': '0'}, []),
#    Annotation(token, 66, 69, Good, {'sentence': '0'}, []),
#    Annotation(token, 71, 77, evening, {'sentence': '0'}, []),
#    Annotation(token, 78, 78, ,, {'sentence': '0'}, []),
#    Annotation(token, 80, 88, Professor, {'sentence': '0'}, []),
#    Annotation(token, 90, 99, Dumbledore, {'sentence': '0'}, []),
#    Annotation(token, 100, 100, ., {'sentence': '0'}, []),
#    Annotation(token, 102, 104, Are, {'sentence': '0'}, []),
#    Annotation(token, 106, 108, the, {'sentence': '0'}, []),
#    Annotation(token, 110, 116, rumours, {'sentence': '0'}, []),
#    Annotation(token, 118, 121, true, {'sentence': '0'}, []),
#    Annotation(token, 123, 127, Albus, {'sentence': '0'}, []),
#    Annotation(token, 128, 128, ?, {'sentence': '0'}, []),
#    Annotation(token, 130, 132, I'm, {'sentence': '0'}, []),
#    Annotation(token, 134, 139, afraid, {'sentence': '0'}, []),
#    Annotation(token, 141, 142, so, {'sentence': '0'}, []),
#    Annotation(token, 143, 143, ,, {'sentence': '0'}, []),
#    Annotation(token, 145, 153, Professor, {'sentence': '0'}, []),
#    Annotation(token, 154, 154, ., {'sentence': '0'}, []),
#    Annotation(token, 156, 158, The, {'sentence': '0'}, []),
#    Annotation(token, 160, 163, good, {'sentence': '0'}, []),
#    Annotation(token, 164, 164, ,, {'sentence': '0'}, []),
#    Annotation(token, 166, 168, and, {'sentence': '0'}, []),
#    Annotation(token, 170, 172, the, {'sentence': '0'}, []),
#    Annotation(token, 174, 176, bad, {'sentence': '0'}, []),
#    Annotation(token, 177, 177, ., {'sentence': '0'}, []),
#    Annotation(token, 179, 181, And, {'sentence': '0'}, []),
#    Annotation(token, 183, 185, the, {'sentence': '0'}, []),
#    Annotation(token, 187, 189, boy, {'sentence': '0'}, []),
#    Annotation(token, 190, 190, ?, {'sentence': '0'}, []),
#    Annotation(token, 192, 197, Hagrid, {'sentence': '0'}, []),
#    Annotation(token, 199, 200, is, {'sentence': '0'}, []),
#    Annotation(token, 202, 209, bringing, {'sentence': '0'}, []),
#    Annotation(token, 211, 213, him, {'sentence': '0'}, []),
#    Annotation(token, 214, 214, ., {'sentence': '0'}, []),
#    Annotation(token, 216, 217, Do, {'sentence': '0'}, []),
#    Annotation(token, 219, 221, you, {'sentence': '0'}, []),
#    Annotation(token, 223, 227, think, {'sentence': '0'}, []),
#    Annotation(token, 229, 230, it, {'sentence': '0'}, []),
#    Annotation(token, 232, 235, wise, {'sentence': '0'}, []),
#    Annotation(token, 237, 238, to, {'sentence': '0'}, []),
#    Annotation(token, 240, 244, trust, {'sentence': '0'}, []),
#    Annotation(token, 246, 251, Hagrid, {'sentence': '0'}, []),
#    Annotation(token, 253, 256, with, {'sentence': '0'}, []),
#    Annotation(token, 258, 266, something, {'sentence': '0'}, []),
#    Annotation(token, 268, 269, as, {'sentence': '0'}, []),
#    Annotation(token, 271, 279, important, {'sentence': '0'}, []),
#    Annotation(token, 281, 282, as, {'sentence': '0'}, []),
#    Annotation(token, 284, 287, this, {'sentence': '0'}, []),
#    Annotation(token, 288, 288, ?, {'sentence': '0'}, []),
#    Annotation(token, 290, 291, Ah, {'sentence': '0'}, []),
#    Annotation(token, 292, 292, ,, {'sentence': '0'}, []),
#    Annotation(token, 294, 302, Professor, {'sentence': '0'}, []),
#    Annotation(token, 303, 303, ,, {'sentence': '0'}, []),
#    Annotation(token, 305, 305, I, {'sentence': '0'}, []),
#    Annotation(token, 307, 311, would, {'sentence': '0'}, []),
#    Annotation(token, 313, 317, trust, {'sentence': '0'}, []),
#    Annotation(token, 319, 324, Hagrid, {'sentence': '0'}, []),
#    Annotation(token, 326, 329, with, {'sentence': '0'}, []),
#    Annotation(token, 331, 332, my, {'sentence': '0'}, []),
#    Annotation(token, 334, 337, life, {'sentence': '0'}, []),
#    Annotation(token, 338, 338, ., {'sentence': '0'}, []),
#    Annotation(token, 340, 348, Professor, {'sentence': '0'}, []),
#    Annotation(token, 350, 359, Dumbledore, {'sentence': '0'}, []),
#    Annotation(token, 360, 360, ,, {'sentence': '0'}, []),
#    Annotation(token, 362, 364, Sir, {'sentence': '0'}, []),
#    Annotation(token, 365, 365, ., {'sentence': '0'}, []),
#    Annotation(token, 367, 375, Professor, {'sentence': '0'}, []),
#    Annotation(token, 377, 386, McGonagall, {'sentence': '0'}, []),
#    Annotation(token, 387, 387, ., {'sentence': '0'}, []),
#    Annotation(token, 389, 390, No, {'sentence': '0'}, []),
#    Annotation(token, 392, 399, problems, {'sentence': '0'}, []),
#    Annotation(token, 400, 400, ,, {'sentence': '0'}, []),
#    Annotation(token, 402, 402, I, {'sentence': '0'}, []),
#    Annotation(token, 404, 408, trust, {'sentence': '0'}, []),
#    Annotation(token, 409, 409, ,, {'sentence': '0'}, []),
#    Annotation(token, 411, 416, Hagrid, {'sentence': '0'}, []),
#    Annotation(token, 417, 417, ?, {'sentence': '0'}, []),
#    Annotation(token, 419, 420, No, {'sentence': '0'}, []),
#    Annotation(token, 421, 421, ,, {'sentence': '0'}, []),
#    Annotation(token, 423, 425, Sir, {'sentence': '0'}, []),
#    Annotation(token, 426, 426, ., {'sentence': '0'}, []),
#    Annotation(token, 428, 433, Little, {'sentence': '0'}, []),
#    Annotation(token, 435, 438, tyke, {'sentence': '0'}, []),
#    Annotation(token, 440, 443, fell, {'sentence': '0'}, []),
#    Annotation(token, 445, 450, asleep, {'sentence': '0'}, []),
#    Annotation(token, 452, 455, just, {'sentence': '0'}, []),
#    Annotation(token, 457, 458, as, {'sentence': '0'}, []),
#    Annotation(token, 460, 461, we, {'sentence': '0'}, []),
#    Annotation(token, 463, 466, were, {'sentence': '0'}, []),
#    Annotation(token, 468, 473, flying, {'sentence': '0'}, []),
#    Annotation(token, 475, 478, over, {'sentence': '0'}, []),
#    Annotation(token, 480, 486, Bristol, {'sentence': '0'}, []),
#    Annotation(token, 487, 487, ., {'sentence': '0'}, []),
#    Annotation(token, 489, 495, Heh.Try, {'sentence': '0'}, []),
#    Annotation(token, 497, 499, not, {'sentence': '0'}, []),
#    Annotation(token, 501, 502, to, {'sentence': '0'}, []),
#    Annotation(token, 504, 507, wake, {'sentence': '0'}, []),
#    Annotation(token, 509, 511, him, {'sentence': '0'}, []),
#    Annotation(token, 512, 512, ., {'sentence': '0'}, []),
#    Annotation(token, 514, 518, There, {'sentence': '0'}, []),
#    Annotation(token, 520, 522, you, {'sentence': '0'}, []),
#    Annotation(token, 524, 525, go, {'sentence': '0'}, []),
#    Annotation(token, 526, 526, ., {'sentence': '0'}, []),
#    Annotation(token, 528, 532, Albus, {'sentence': '0'}, []),
#    Annotation(token, 533, 533, ,, {'sentence': '0'}, []),
#    Annotation(token, 535, 536, do, {'sentence': '0'}, []),
#    Annotation(token, 538, 540, you, {'sentence': '0'}, []),
#    Annotation(token, 542, 547, really, {'sentence': '0'}, []),
#    Annotation(token, 549, 553, think, {'sentence': '0'}, []),
#    Annotation(token, 555, 558, it's, {'sentence': '0'}, []),
#    Annotation(token, 560, 563, safe, {'sentence': '0'}, []),
#    Annotation(token, 564, 564, ,, {'sentence': '0'}, []),
#    Annotation(token, 566, 572, leaving, {'sentence': '0'}, []),
#    Annotation(token, 574, 576, him, {'sentence': '0'}, []),
#    Annotation(token, 578, 581, with, {'sentence': '0'}, []),
#    Annotation(token, 583, 587, these, {'sentence': '0'}, []),
#    Annotation(token, 589, 594, people, {'sentence': '0'}, []),
#    Annotation(token, 595, 595, ?, {'sentence': '0'}, []),
#    Annotation(token, 597, 600, I've, {'sentence': '0'}, []),
#    Annotation(token, 602, 608, watched, {'sentence': '0'}, []),
#    Annotation(token, 610, 613, them, {'sentence': '0'}, []),
#    Annotation(token, 615, 617, all, {'sentence': '0'}, []),
#    Annotation(token, 619, 621, day, {'sentence': '0'}, []),
#    Annotation(token, 622, 622, ., {'sentence': '0'}, []),
#    Annotation(token, 624, 630, They're, {'sentence': '0'}, []),
#    Annotation(token, 632, 634, the, {'sentence': '0'}, []),
#    Annotation(token, 636, 640, worst, {'sentence': '0'}, []),
#    Annotation(token, 642, 645, sort, {'sentence': '0'}, []),
#    Annotation(token, 647, 648, of, {'sentence': '0'}, []),
#    Annotation(token, 650, 656, Muggles, {'sentence': '0'}, []),
#    Annotation(token, 658, 667, imaginable, {'sentence': '0'}, []),
#    Annotation(token, 668, 668, ., {'sentence': '0'}, []),
#    Annotation(token, 670, 673, They, {'sentence': '0'}, []),
#    Annotation(token, 675, 680, really, {'sentence': '0'}, []),
#    Annotation(token, 682, 684, are, {'sentence': '0'}, []),
#    Annotation(token, 686, 688, The, {'sentence': '0'}, []),
#    Annotation(token, 690, 693, only, {'sentence': '0'}, []),
#    Annotation(token, 695, 700, family, {'sentence': '0'}, []),
#    Annotation(token, 702, 703, he, {'sentence': '0'}, []),
#    Annotation(token, 705, 707, has, {'sentence': '0'}, []),
#    Annotation(token, 708, 708, ., {'sentence': '0'}, []),
#    Annotation(token, 710, 713, This, {'sentence': '0'}, []),
#    Annotation(token, 715, 717, boy, {'sentence': '0'}, []),
#    Annotation(token, 719, 722, will, {'sentence': '0'}, []),
#    Annotation(token, 724, 725, be, {'sentence': '0'}, []),
#    Annotation(token, 727, 732, famous, {'sentence': '0'}, []),
#    Annotation(token, 733, 733, ., {'sentence': '0'}, []),
#    Annotation(token, 735, 739, There, {'sentence': '0'}, []),
#    Annotation(token, 741, 745, won't, {'sentence': '0'}, []),
#    Annotation(token, 747, 748, be, {'sentence': '0'}, []),
#    Annotation(token, 750, 750, a, {'sentence': '0'}, []),
#    Annotation(token, 752, 756, child, {'sentence': '0'}, []),
#    Annotation(token, 758, 759, in, {'sentence': '0'}, []),
#    Annotation(token, 761, 763, our, {'sentence': '0'}, []),
#    Annotation(token, 765, 769, world, {'sentence': '0'}, []),
#    Annotation(token, 771, 773, who, {'sentence': '0'}, []),
#    Annotation(token, 775, 781, doesn't, {'sentence': '0'}, []),
#    Annotation(token, 783, 786, know, {'sentence': '0'}, []),
#    Annotation(token, 788, 790, his, {'sentence': '0'}, []),
#    Annotation(token, 792, 795, name, {'sentence': '0'}, []),
#    Annotation(token, 796, 796, ., {'sentence': '0'}, []),
#    Annotation(token, 798, 804, Exactly, {'sentence': '0'}, []),
#    Annotation(token, 805, 805, ., {'sentence': '0'}, []),
#    Annotation(token, 807, 810, He's, {'sentence': '0'}, []),
#    Annotation(token, 812, 814, far, {'sentence': '0'}, []),
#    Annotation(token, 816, 821, better, {'sentence': '0'}, []),
#    Annotation(token, 823, 825, off, {'sentence': '0'}, []),
#    Annotation(token, 827, 833, growing, {'sentence': '0'}, []),
#    Annotation(token, 835, 836, up, {'sentence': '0'}, []),
#    Annotation(token, 838, 841, away, {'sentence': '0'}, []),
#    Annotation(token, 843, 846, from, {'sentence': '0'}, []),
#    Annotation(token, 848, 850, all, {'sentence': '0'}, []),
#    Annotation(token, 852, 853, of, {'sentence': '0'}, []),
#    Annotation(token, 855, 858, that, {'sentence': '0'}, []),
#    Annotation(token, 859, 859, ., {'sentence': '0'}, []),
#    Annotation(token, 861, 865, Until, {'sentence': '0'}, []),
#    Annotation(token, 867, 868, he, {'sentence': '0'}, []),
#    Annotation(token, 870, 871, is, {'sentence': '0'}, []),
#    Annotation(token, 873, 877, ready, {'sentence': '0'}, []),
#    Annotation(token, 878, 878, ., {'sentence': '0'}, []),
#    Annotation(token, 880, 884, There, {'sentence': '0'}, []),
#    Annotation(token, 886, 890, there, {'sentence': '0'}, []),
#    Annotation(token, 891, 891, ,, {'sentence': '0'}, []),
#    Annotation(token, 893, 898, Hagrid, {'sentence': '0'}, []),
#    Annotation(token, 899, 899, ., {'sentence': '0'}, []),
#    Annotation(token, 901, 904, It's, {'sentence': '0'}, []),
#    Annotation(token, 906, 908, not, {'sentence': '0'}, []),
#    Annotation(token, 910, 915, really, {'sentence': '0'}, []),
#    Annotation(token, 917, 923, goodbye, {'sentence': '0'}, []),
#    Annotation(token, 924, 924, ,, {'sentence': '0'}, []),
#    Annotation(token, 926, 930, after, {'sentence': '0'}, []),
#    Annotation(token, 932, 934, all, {'sentence': '0'}, []),
#    Annotation(token, 935, 935, ., {'sentence': '0'}, []),
#    Annotation(token, 937, 940, Good, {'sentence': '0'}, []),
#    Annotation(token, 942, 945, luck, {'sentence': '0'}, []),
#    Annotation(token, 946, 946, ,, {'sentence': '0'}, []),
#    Annotation(token, 948, 952, Harry, {'sentence': '0'}, []),
#    Annotation(token, 954, 959, Potter, {'sentence': '0'}, []),
#    Annotation(token, 960, 960, ., {'sentence': '0'}, []),
#    Annotation(token, 962, 963, Up, {'sentence': '0'}, []),
#    Annotation(token, 964, 964, ., {'sentence': '0'}, []),
#    Annotation(token, 966, 968, Get, {'sentence': '0'}, []),
#    Annotation(token, 970, 971, up, {'sentence': '0'}, []),
#    Annotation(token, 972, 972, ., {'sentence': '0'}, []),
#    Annotation(token, 974, 976, Now, {'sentence': '0'}, []),
#    Annotation(token, 977, 977, !, {'sentence': '0'}, []),
#    Annotation(token, 979, 982, Wake, {'sentence': '0'}, []),
#    Annotation(token, 984, 985, up, {'sentence': '0'}, []),
#    Annotation(token, 986, 986, ,, {'sentence': '0'}, []),
#    Annotation(token, 988, 993, cousin, {'sentence': '0'}, []),
#    Annotation(token, 994, 994, !, {'sentence': '0'}, []),
#    Annotation(token, 996, 1000, We're, {'sentence': '0'}, []),
#    Annotation(token, 1002, 1006, going, {'sentence': '0'}, []),
#    Annotation(token, 1008, 1009, to, {'sentence': '0'}, []),
#    Annotation(token, 1011, 1013, the, {'sentence': '0'}, []),
#    Annotation(token, 1015, 1017, zoo, {'sentence': '0'}, []),
#    Annotation(token, 1018, 1018, !, {'sentence': '0'}, []),
#    Annotation(token, 1020, 1021, Oh, {'sentence': '0'}, []),
#    Annotation(token, 1022, 1022, ,, {'sentence': '0'}, []),
#    Annotation(token, 1024, 1027, here, {'sentence': '0'}, []),
#    Annotation(token, 1029, 1030, he, {'sentence': '0'}, []),
#    Annotation(token, 1032, 1036, comes, {'sentence': '0'}, []),
#    Annotation(token, 1037, 1037, ,, {'sentence': '0'}, []),
#    Annotation(token, 1039, 1041, the, {'sentence': '0'}, []),
#    Annotation(token, 1043, 1050, birthday, {'sentence': '0'}, []),
#    Annotation(token, 1052, 1054, boy, {'sentence': '0'}, []),
#    Annotation(token, 1055, 1055, !, {'sentence': '0'}, []),
#    Annotation(token, 1057, 1061, Happy, {'sentence': '0'}, []),
#    Annotation(token, 1063, 1070, birthday, {'sentence': '0'}, []),
#    Annotation(token, 1071, 1071, ,, {'sentence': '0'}, []),
#    Annotation(token, 1073, 1075, son, {'sentence': '0'}, []),
#    Annotation(token, 1076, 1076, ., {'sentence': '0'}, []),
#    Annotation(token, 1078, 1080, Why, {'sentence': '0'}, []),
#    Annotation(token, 1082, 1086, don't, {'sentence': '0'}, []),
#    Annotation(token, 1088, 1090, you, {'sentence': '0'}, []),
#    Annotation(token, 1092, 1095, just, {'sentence': '0'}, []),
#    Annotation(token, 1097, 1100, cook, {'sentence': '0'}, []),
#    Annotation(token, 1102, 1104, the, {'sentence': '0'}, []),
#    Annotation(token, 1106, 1114, breakfast, {'sentence': '0'}, []),
#    Annotation(token, 1115, 1115, ,, {'sentence': '0'}, []),
#    Annotation(token, 1117, 1119, and, {'sentence': '0'}, []),
#    Annotation(token, 1121, 1123, try, {'sentence': '0'}, []),
#    Annotation(token, 1125, 1127, not, {'sentence': '0'}, []),
#    Annotation(token, 1129, 1130, to, {'sentence': '0'}, []),
#    Annotation(token, 1132, 1135, burn, {'sentence': '0'}, []),
#    Annotation(token, 1137, 1144, anything, {'sentence': '0'}, []),
#    Annotation(token, 1145, 1145, ., {'sentence': '0'}, []),
#    Annotation(token, 1147, 1149, Yes, {'sentence': '0'}, []),
#    Annotation(token, 1150, 1150, ,, {'sentence': '0'}, []),
#    Annotation(token, 1152, 1155, Aunt, {'sentence': '0'}, []),
#    Annotation(token, 1157, 1163, Petunia, {'sentence': '0'}, []),
#    Annotation(token, 1164, 1164, ., {'sentence': '0'}, []),
#    Annotation(token, 1166, 1166, I, {'sentence': '0'}, []),
#    Annotation(token, 1168, 1171, want, {'sentence': '0'}, []),
#    Annotation(token, 1173, 1182, everything, {'sentence': '0'}, []),
#    Annotation(token, 1184, 1185, to, {'sentence': '0'}, []),
#    Annotation(token, 1187, 1188, be, {'sentence': '0'}, []),
#    Annotation(token, 1190, 1196, perfect, {'sentence': '0'}, []),
#    Annotation(token, 1198, 1200, for, {'sentence': '0'}, []),
#    Annotation(token, 1202, 1203, my, {'sentence': '0'}, []),
#    Annotation(token, 1205, 1212, Dudley's, {'sentence': '0'}, []),
#    Annotation(token, 1214, 1220, special, {'sentence': '0'}, []),
#    Annotation(token, 1222, 1224, day, {'sentence': '0'}, []),
#    Annotation(token, 1225, 1225, ., {'sentence': '0'}, []),
#    Annotation(token, 1227, 1231, Hurry, {'sentence': '0'}, []),
#    Annotation(token, 1233, 1234, up, {'sentence': '0'}, []),
#    Annotation(token, 1235, 1235, !, {'sentence': '0'}, []),
#    Annotation(token, 1237, 1241, Bring, {'sentence': '0'}, []),
#    Annotation(token, 1243, 1244, my, {'sentence': '0'}, []),
#    Annotation(token, 1246, 1251, coffee, {'sentence': '0'}, []),
#    Annotation(token, 1252, 1252, ,, {'sentence': '0'}, []),
#    Annotation(token, 1254, 1256, boy, {'sentence': '0'}, []),
#    Annotation(token, 1257, 1257, !, {'sentence': '0'}, []),
#    Annotation(token, 1259, 1261, Yes, {'sentence': '0'}, []),
#    Annotation(token, 1262, 1262, ,, {'sentence': '0'}, []),
#    Annotation(token, 1264, 1268, Uncle, {'sentence': '0'}, []),
#    Annotation(token, 1270, 1275, Vernon, {'sentence': '0'}, []),
#    Annotation(token, 1276, 1276, ., {'sentence': '0'}, []),
#    Annotation(token, 1278, 1283, Aren't, {'sentence': '0'}, []),
#    Annotation(token, 1285, 1288, they, {'sentence': '0'}, []),
#    Annotation(token, 1290, 1298, wonderful, {'sentence': '0'}, []),
#    Annotation(token, 1299, 1299, ,, {'sentence': '0'}, []),
#    Annotation(token, 1301, 1307, darling, {'sentence': '0'}, []),
#    Annotation(token, 1308, 1308, ?, {'sentence': '0'}, []),
#    Annotation(token, 1310, 1312, How, {'sentence': '0'}, []),
#    Annotation(token, 1314, 1317, many, {'sentence': '0'}, []),
#    Annotation(token, 1319, 1321, are, {'sentence': '0'}, []),
#    Annotation(token, 1323, 1327, there, {'sentence': '0'}, []),
#    Annotation(token, 1328, 1328, ?, {'sentence': '0'}, []),
#    Annotation(token, 1330, 1339, Thirty-six, {'sentence': '0'}, []),
#    Annotation(token, 1340, 1340, ., {'sentence': '0'}, []),
#    Annotation(token, 1342, 1348, Counted, {'sentence': '0'}, []),
#    Annotation(token, 1350, 1353, them, {'sentence': '0'}, []),
#    Annotation(token, 1355, 1360, myself, {'sentence': '0'}, []),
#    Annotation(token, 1361, 1361, ., {'sentence': '0'}, []),
#    Annotation(token, 1363, 1372, Thirty-six, {'sentence': '0'}, []),
#    Annotation(token, 1373, 1374, ?!, {'sentence': '0'}, []),
#    Annotation(token, 1376, 1378, But, {'sentence': '0'}, []),
#    Annotation(token, 1380, 1383, last, {'sentence': '0'}, []),
#    Annotation(token, 1385, 1388, year, {'sentence': '0'}, []),
#    Annotation(token, 1389, 1389, ,, {'sentence': '0'}, []),
#    Annotation(token, 1391, 1394, last, {'sentence': '0'}, []),
#    Annotation(token, 1396, 1399, year, {'sentence': '0'}, []),
#    Annotation(token, 1401, 1401, I, {'sentence': '0'}, []),
#    Annotation(token, 1403, 1405, had, {'sentence': '0'}, []),
#    Annotation(token, 1407, 1418, thirty-seven, {'sentence': '0'}, []),
#    Annotation(token, 1419, 1419, !, {'sentence': '0'}, []),
#    Annotation(token, 1421, 1423, Err, {'sentence': '0'}, []),
#    Annotation(token, 1425, 1427, yes, {'sentence': '0'}, []),
#    Annotation(token, 1428, 1428, ,, {'sentence': '0'}, []),
#    Annotation(token, 1430, 1433, well, {'sentence': '0'}, []),
#    Annotation(token, 1434, 1434, ,, {'sentence': '0'}, []),
#    Annotation(token, 1436, 1439, some, {'sentence': '0'}, []),
#    Annotation(token, 1441, 1442, of, {'sentence': '0'}, []),
#    Annotation(token, 1444, 1447, them, {'sentence': '0'}, []),
#    Annotation(token, 1449, 1451, are, {'sentence': '0'}, []),
#    Annotation(token, 1453, 1457, quite, {'sentence': '0'}, []),
#    Annotation(token, 1459, 1459, a, {'sentence': '0'}, []),
#    Annotation(token, 1461, 1463, bit, {'sentence': '0'}, []),
#    Annotation(token, 1465, 1470, bigger, {'sentence': '0'}, []),
#    Annotation(token, 1472, 1475, than, {'sentence': '0'}, []),
#    Annotation(token, 1477, 1480, last, {'sentence': '0'}, []),
#    Annotation(token, 1482, 1485, year, {'sentence': '0'}, []),
#    Annotation(token, 1486, 1486, ., {'sentence': '0'}, []),
#    Annotation(token, 1488, 1488, I, {'sentence': '0'}, []),
#    Annotation(token, 1490, 1494, don't, {'sentence': '0'}, []),
#    Annotation(token, 1496, 1499, care, {'sentence': '0'}, []),
#    Annotation(token, 1501, 1503, how, {'sentence': '0'}, []),
#    Annotation(token, 1505, 1507, big, {'sentence': '0'}, []),
#    Annotation(token, 1509, 1512, they, {'sentence': '0'}, []),
#    Annotation(token, 1514, 1516, are, {'sentence': '0'}, []),
#    Annotation(token, 1517, 1517, !, {'sentence': '0'}, []),
#    Annotation(token, 1519, 1520, Oh, {'sentence': '0'}, []),
#    Annotation(token, 1521, 1521, ,, {'sentence': '0'}, []),
#    Annotation(token, 1523, 1525, now, {'sentence': '0'}, []),
#    Annotation(token, 1526, 1526, ,, {'sentence': '0'}, []),
#    Annotation(token, 1528, 1530, now, {'sentence': '0'}, []),
#    Annotation(token, 1531, 1531, ,, {'sentence': '0'}, []),
#    Annotation(token, 1533, 1535, now, {'sentence': '0'}, []),
#    Annotation(token, 1536, 1536, ., {'sentence': '0'}, []),
#    Annotation(token, 1538, 1541, This, {'sentence': '0'}, []),
#    Annotation(token, 1543, 1544, is, {'sentence': '0'}, []),
#    Annotation(token, 1546, 1549, what, {'sentence': '0'}, []),
#    Annotation(token, 1551, 1555, we're, {'sentence': '0'}, []),
#    Annotation(token, 1557, 1561, going, {'sentence': '0'}, []),
#    Annotation(token, 1563, 1564, to, {'sentence': '0'}, []),
#    Annotation(token, 1566, 1567, do, {'sentence': '0'}, []),
#    Annotation(token, 1568, 1568, ,, {'sentence': '0'}, []),
#    Annotation(token, 1570, 1571, is, {'sentence': '0'}, []),
#    Annotation(token, 1573, 1576, that, {'sentence': '0'}, []),
#    Annotation(token, 1578, 1581, when, {'sentence': '0'}, []),
#    Annotation(token, 1583, 1584, we, {'sentence': '0'}, []),
#    Annotation(token, 1586, 1587, go, {'sentence': '0'}, []),
#    Annotation(token, 1589, 1591, out, {'sentence': '0'}, []),
#    Annotation(token, 1592, 1592, ,, {'sentence': '0'}, []),
#    Annotation(token, 1594, 1598, we're, {'sentence': '0'}, []),
#    Annotation(token, 1600, 1604, going, {'sentence': '0'}, []),
#    Annotation(token, 1606, 1607, to, {'sentence': '0'}, []),
#    Annotation(token, 1609, 1611, buy, {'sentence': '0'}, []),
#    Annotation(token, 1613, 1615, you, {'sentence': '0'}, []),
#    Annotation(token, 1617, 1619, two, {'sentence': '0'}, []),
#    Annotation(token, 1621, 1623, new, {'sentence': '0'}, []),
#    Annotation(token, 1625, 1632, presents, {'sentence': '0'}, []),
#    Annotation(token, 1633, 1633, !, {'sentence': '0'}, []),
#    Annotation(token, 1635, 1639, How's, {'sentence': '0'}, []),
#    Annotation(token, 1641, 1644, that, {'sentence': '0'}, []),
#    Annotation(token, 1645, 1645, ,, {'sentence': '0'}, []),
#    Annotation(token, 1647, 1653, pumpkin, {'sentence': '0'}, []),
#    Annotation(token, 1654, 1654, ?, {'sentence': '0'}, []),
#    Annotation(token, 1656, 1659, This, {'sentence': '0'}, []),
#    Annotation(token, 1661, 1664, will, {'sentence': '0'}, []),
#    Annotation(token, 1666, 1667, be, {'sentence': '0'}, []),
#    Annotation(token, 1669, 1669, a, {'sentence': '0'}, []),
#    Annotation(token, 1671, 1676, lovely, {'sentence': '0'}, []),
#    Annotation(token, 1678, 1680, day, {'sentence': '0'}, []),
#    Annotation(token, 1682, 1683, at, {'sentence': '0'}, []),
#    Annotation(token, 1685, 1687, the, {'sentence': '0'}, []),
#    Annotation(token, 1689, 1691, zoo, {'sentence': '0'}, []),
#    Annotation(token, 1692, 1692, ., {'sentence': '0'}, []),
#    Annotation(token, 1694, 1696, I'm, {'sentence': '0'}, []),
#    Annotation(token, 1698, 1703, really, {'sentence': '0'}, []),
#    Annotation(token, 1705, 1711, looking, {'sentence': '0'}, []),
#    Annotation(token, 1713, 1719, forward, {'sentence': '0'}, []),
#    Annotation(token, 1721, 1722, to, {'sentence': '0'}, []),
#    Annotation(token, 1724, 1725, it, {'sentence': '0'}, []),
#    Annotation(token, 1726, 1726, ., {'sentence': '0'}, []),
#    Annotation(token, 1728, 1730, I'm, {'sentence': '0'}, []),
#    Annotation(token, 1732, 1738, warning, {'sentence': '0'}, []),
#    Annotation(token, 1740, 1742, you, {'sentence': '0'}, []),
#    Annotation(token, 1744, 1746, now, {'sentence': '0'}, []),
#    Annotation(token, 1747, 1747, ,, {'sentence': '0'}, []),
#    Annotation(token, 1749, 1751, boy, {'sentence': '0'}, []),
#    Annotation(token, 1752, 1752, ., {'sentence': '0'}, []),
#    Annotation(token, 1754, 1756, Any, {'sentence': '0'}, []),
#    Annotation(token, 1758, 1762, funny, {'sentence': '0'}, []),
#    Annotation(token, 1764, 1771, business, {'sentence': '0'}, []),
#    Annotation(token, 1772, 1772, ,, {'sentence': '0'}, []),
#    Annotation(token, 1774, 1776, any, {'sentence': '0'}, []),
#    Annotation(token, 1778, 1779, at, {'sentence': '0'}, []),
#    Annotation(token, 1781, 1783, all, {'sentence': '0'}, []),
#    Annotation(token, 1784, 1784, ,, {'sentence': '0'}, []),
#    Annotation(token, 1786, 1788, and, {'sentence': '0'}, []),
#    Annotation(token, 1790, 1792, you, {'sentence': '0'}, []),
#    Annotation(token, 1794, 1798, won't, {'sentence': '0'}, []),
#    Annotation(token, 1800, 1803, have, {'sentence': '0'}, []),
#    Annotation(token, 1805, 1807, any, {'sentence': '0'}, []),
#    Annotation(token, 1809, 1813, meals, {'sentence': '0'}, []),
#    Annotation(token, 1815, 1817, for, {'sentence': '0'}, []),
#    Annotation(token, 1819, 1819, a, {'sentence': '0'}, []),
#    Annotation(token, 1821, 1824, week, {'sentence': '0'}, []),
#    Annotation(token, 1825, 1825, ., {'sentence': '0'}, []),
#    Annotation(token, 1827, 1829, Get, {'sentence': '0'}, []),
#    Annotation(token, 1831, 1832, in, {'sentence': '0'}, []),
#    Annotation(token, 1833, 1833, ., {'sentence': '0'}, []),
#    Annotation(token, 1835, 1838, Make, {'sentence': '0'}, []),
#    Annotation(token, 1840, 1841, it, {'sentence': '0'}, []),
#    Annotation(token, 1843, 1846, move, {'sentence': '0'}, []),
#    Annotation(token, 1847, 1847, ., {'sentence': '0'}, []),
#    Annotation(token, 1849, 1852, Move, {'sentence': '0'}, []),
#    Annotation(token, 1853, 1853, !, {'sentence': '0'}, []),
#    Annotation(token, 1855, 1858, MOVE, {'sentence': '0'}, []),
#    Annotation(token, 1859, 1859, !, {'sentence': '0'}, []),
#    Annotation(token, 1861, 1864, He's, {'sentence': '0'}, []),
#    Annotation(token, 1866, 1871, asleep, {'sentence': '0'}, []),
#    Annotation(token, 1872, 1872, !, {'sentence': '0'}, []),
#    Annotation(token, 1874, 1877, He's, {'sentence': '0'}, []),
#    Annotation(token, 1879, 1884, boring, {'sentence': '0'}, []),
#    Annotation(token, 1885, 1885, ., {'sentence': '0'}, []),
#    Annotation(token, 1887, 1891, Sorry, {'sentence': '0'}, []),
#    Annotation(token, 1893, 1897, about, {'sentence': '0'}, []),
#    Annotation(token, 1899, 1901, him, {'sentence': '0'}, []),
#    Annotation(token, 1902, 1902, ., {'sentence': '0'}, []),
#    Annotation(token, 1904, 1905, He, {'sentence': '0'}, []),
#    Annotation(token, 1907, 1913, doesn't, {'sentence': '0'}, []),
#    Annotation(token, 1915, 1924, understand, {'sentence': '0'}, []),
#    Annotation(token, 1926, 1929, what, {'sentence': '0'}, []),
#    Annotation(token, 1931, 1934, it's, {'sentence': '0'}, []),
#    Annotation(token, 1936, 1939, like, {'sentence': '0'}, []),
#    Annotation(token, 1940, 1940, ,, {'sentence': '0'}, []),
#    Annotation(token, 1942, 1946, lying, {'sentence': '0'}, []),
#    Annotation(token, 1948, 1952, there, {'sentence': '0'}, []),
#    Annotation(token, 1954, 1956, day, {'sentence': '0'}, []),
#    Annotation(token, 1958, 1962, after, {'sentence': '0'}, []),
#    Annotation(token, 1964, 1966, day, {'sentence': '0'}, []),
#    Annotation(token, 1967, 1967, ,, {'sentence': '0'}, []),
#    Annotation(token, 1969, 1974, having, {'sentence': '0'}, []),
#    Annotation(token, 1976, 1981, people, {'sentence': '0'}, []),
#    Annotation(token, 1983, 1987, press, {'sentence': '0'}, []),
#    Annotation(token, 1989, 1993, their, {'sentence': '0'}, []),
#    Annotation(token, 1995, 1998, ugly, {'sentence': '0'}, []),
#    Annotation(token, 2000, 2004, faces, {'sentence': '0'}, []),
#    Annotation(token, 2006, 2007, in, {'sentence': '0'}, []),
#    Annotation(token, 2009, 2010, on, {'sentence': '0'}, []),
#    Annotation(token, 2012, 2014, you, {'sentence': '0'}, []),
#    Annotation(token, 2015, 2015, ., {'sentence': '0'}, []),
#    Annotation(token, 2017, 2019, Can, {'sentence': '0'}, []),
#    Annotation(token, 2021, 2023, you, {'sentence': '0'}, []),
#    Annotation(token, 2025, 2028, hear, {'sentence': '0'}, []),
#    Annotation(token, 2030, 2031, me, {'sentence': '0'}, []),
#    Annotation(token, 2032, 2032, ?, {'sentence': '0'}, []),
#    Annotation(token, 2034, 2037, It's, {'sentence': '0'}, []),
#    Annotation(token, 2039, 2042, just, {'sentence': '0'}, []),
#    Annotation(token, 2044, 2047, I've, {'sentence': '0'}, []),
#    Annotation(token, 2049, 2053, never, {'sentence': '0'}, []),
#    Annotation(token, 2055, 2060, talked, {'sentence': '0'}, []),
#    Annotation(token, 2062, 2063, to, {'sentence': '0'}, []),
#    Annotation(token, 2065, 2065, a, {'sentence': '0'}, []),
#    Annotation(token, 2067, 2071, snake, {'sentence': '0'}, []),
#    Annotation(token, 2073, 2078, before, {'sentence': '0'}, []),
#    Annotation(token, 2079, 2079, ., {'sentence': '0'}, []),
#    Annotation(token, 2081, 2082, Do, {'sentence': '0'}, []),
#    Annotation(token, 2084, 2086, you, {'sentence': '0'}, []),
#    Annotation(token, 2088, 2088, I, {'sentence': '0'}, []),
#    Annotation(token, 2090, 2093, mean, {'sentence': '0'}, []),
#    Annotation(token, 2095, 2096, do, {'sentence': '0'}, []),
#    Annotation(token, 2098, 2100, you, {'sentence': '0'}, []),
#    Annotation(token, 2102, 2105, talk, {'sentence': '0'}, []),
#    Annotation(token, 2107, 2108, to, {'sentence': '0'}, []),
#    Annotation(token, 2110, 2115, people, {'sentence': '0'}, []),
#    Annotation(token, 2117, 2121, often, {'sentence': '0'}, []),
#    Annotation(token, 2122, 2122, ?, {'sentence': '0'}, []),
#    Annotation(token, 2124, 2129, You're, {'sentence': '0'}, []),
#    Annotation(token, 2131, 2134, from, {'sentence': '0'}, []),
#    Annotation(token, 2136, 2140, Burma, {'sentence': '0'}, []),
#    Annotation(token, 2141, 2141, ,, {'sentence': '0'}, []),
#    Annotation(token, 2143, 2148, aren't, {'sentence': '0'}, []),
#    Annotation(token, 2150, 2152, you, {'sentence': '0'}, []),
#    Annotation(token, 2153, 2153, ?, {'sentence': '0'}, []),
#    Annotation(token, 2155, 2157, Was, {'sentence': '0'}, []),
#    Annotation(token, 2159, 2160, it, {'sentence': '0'}, []),
#    Annotation(token, 2162, 2165, nice, {'sentence': '0'}, []),
#    Annotation(token, 2167, 2171, there, {'sentence': '0'}, []),
#    Annotation(token, 2172, 2172, ,, {'sentence': '0'}, []),
#    Annotation(token, 2174, 2175, do, {'sentence': '0'}, []),
#    Annotation(token, 2177, 2179, you, {'sentence': '0'}, []),
#    Annotation(token, 2181, 2184, miss, {'sentence': '0'}, []),
#    Annotation(token, 2186, 2189, your, {'sentence': '0'}, []),
#    Annotation(token, 2191, 2196, family, {'sentence': '0'}, []),
#    Annotation(token, 2197, 2197, ?, {'sentence': '0'}, []),
#    Annotation(token, 2199, 2199, I, {'sentence': '0'}, []),
#    Annotation(token, 2201, 2203, see, {'sentence': '0'}, []),
#    Annotation(token, 2204, 2204, ., {'sentence': '0'}, []),
#    Annotation(token, 2206, 2211, That's, {'sentence': '0'}, []),
#    Annotation(token, 2213, 2214, me, {'sentence': '0'}, []),
#    Annotation(token, 2216, 2217, as, {'sentence': '0'}, []),
#    Annotation(token, 2219, 2222, well, {'sentence': '0'}, []),
#    Annotation(token, 2223, 2223, ., {'sentence': '0'}, []),
#    Annotation(token, 2225, 2225, I, {'sentence': '0'}, []),
#    Annotation(token, 2227, 2231, never, {'sentence': '0'}, []),
#    Annotation(token, 2233, 2236, knew, {'sentence': '0'}, []),
#    Annotation(token, 2238, 2239, my, {'sentence': '0'}, []),
#    Annotation(token, 2241, 2247, parents, {'sentence': '0'}, []),
#    Annotation(token, 2248, 2248, ,, {'sentence': '0'}, []),
#    Annotation(token, 2250, 2255, either, {'sentence': '0'}, []),
#    Annotation(token, 2256, 2256, ., {'sentence': '0'}, []),
#    Annotation(token, 2258, 2262, Mummy, {'sentence': '0'}, []),
#    Annotation(token, 2263, 2263, ,, {'sentence': '0'}, []),
#    Annotation(token, 2265, 2267, dad, {'sentence': '0'}, []),
#    Annotation(token, 2268, 2268, ,, {'sentence': '0'}, []),
#    Annotation(token, 2270, 2273, come, {'sentence': '0'}, []),
#    Annotation(token, 2275, 2278, here, {'sentence': '0'}, []),
#    Annotation(token, 2279, 2279, !, {'sentence': '0'}, []),
#    Annotation(token, 2281, 2283, You, {'sentence': '0'}, []),
#    Annotation(token, 2285, 2289, won't, {'sentence': '0'}, []),
#    Annotation(token, 2291, 2297, believe, {'sentence': '0'}, []),
#    Annotation(token, 2299, 2302, what, {'sentence': '0'}, []),
#    Annotation(token, 2304, 2307, this, {'sentence': '0'}, []),
#    Annotation(token, 2309, 2313, snake, {'sentence': '0'}, []),
#    Annotation(token, 2315, 2316, is, {'sentence': '0'}, []),
#    Annotation(token, 2318, 2322, doing, {'sentence': '0'}, []),
#    Annotation(token, 2323, 2323, !, {'sentence': '0'}, []),
#    Annotation(token, 2325, 2328, Whoa, {'sentence': '0'}, []),
#    Annotation(token, 2329, 2329, !, {'sentence': '0'}, []),
#    Annotation(token, 2331, 2333, Ahh, {'sentence': '0'}, []),
#    Annotation(token, 2334, 2334, !, {'sentence': '0'}, []),
#    Annotation(token, 2336, 2338, Ahh, {'sentence': '0'}, []),
#    Annotation(token, 2339, 2340, !!, {'sentence': '0'}, []),
#    Annotation(token, 2342, 2347, Thanks, {'sentence': '0'}, []),
#    Annotation(token, 2348, 2348, ., {'sentence': '0'}, []),
#    Annotation(token, 2350, 2352, Any, {'sentence': '0'}, []),
#    Annotation(token, 2354, 2357, time, {'sentence': '0'}, []),
#    Annotation(token, 2358, 2358, ., {'sentence': '0'}, []),
#    Annotation(token, 2360, 2362, Mum, {'sentence': '0'}, []),
#    Annotation(token, 2363, 2363, ,, {'sentence': '0'}, []),
#    Annotation(token, 2365, 2369, mummy, {'sentence': '0'}, []),
#    Annotation(token, 2370, 2370, !, {'sentence': '0'}, []),
#    Annotation(token, 2372, 2374, AHH, {'sentence': '0'}, []),
#    Annotation(token, 2375, 2375, !, {'sentence': '0'}, []),
#    Annotation(token, 2377, 2379, Mum, {'sentence': '0'}, []),
#    Annotation(token, 2380, 2380, ,, {'sentence': '0'}, []),
#    Annotation(token, 2382, 2385, help, {'sentence': '0'}, []),
#    Annotation(token, 2386, 2386, !, {'sentence': '0'}, []),
#    Annotation(token, 2388, 2391, Help, {'sentence': '0'}, []),
#    Annotation(token, 2393, 2394, me, {'sentence': '0'}, []),
#    Annotation(token, 2395, 2395, !, {'sentence': '0'}, []),
#    Annotation(token, 2397, 2398, My, {'sentence': '0'}, []),
#    Annotation(token, 2400, 2406, darling, {'sentence': '0'}, []),
#    Annotation(token, 2408, 2410, boy, {'sentence': '0'}, []),
#    Annotation(token, 2411, 2411, !, {'sentence': '0'}, []),
#    Annotation(token, 2413, 2415, How, {'sentence': '0'}, []),
#    Annotation(token, 2417, 2419, did, {'sentence': '0'}, []),
#    Annotation(token, 2421, 2423, you, {'sentence': '0'}, []),
#    Annotation(token, 2425, 2427, get, {'sentence': '0'}, []),
#    Annotation(token, 2429, 2430, in, {'sentence': '0'}, []),
#    Annotation(token, 2432, 2436, there, {'sentence': '0'}, []),
#    Annotation(token, 2437, 2438, ?!, {'sentence': '0'}, []),
#    Annotation(token, 2440, 2442, How, {'sentence': '0'}, []),
#    Annotation(token, 2444, 2446, did, {'sentence': '0'}, []),
#    Annotation(token, 2448, 2450, you, {'sentence': '0'}, []),
#    Annotation(token, 2452, 2454, get, {'sentence': '0'}, []),
#    Annotation(token, 2456, 2457, in, {'sentence': '0'}, []),
#    Annotation(token, 2459, 2463, there, {'sentence': '0'}, []),
#    Annotation(token, 2464, 2464, ?, {'sentence': '0'}, []),
#    Annotation(token, 2466, 2472, Dursley, {'sentence': '0'}, []),
#    Annotation(token, 2473, 2473, ,, {'sentence': '0'}, []),
#    Annotation(token, 2475, 2476, oh, {'sentence': '0'}, []),
#    Annotation(token, 2477, 2477, ,, {'sentence': '0'}, []),
#    Annotation(token, 2479, 2485, Dursley, {'sentence': '0'}, []),
#    Annotation(token, 2486, 2486, !, {'sentence': '0'}, []),
#    Annotation(token, 2488, 2491, It's, {'sentence': '0'}, []),
#    Annotation(token, 2493, 2495, all, {'sentence': '0'}, []),
#    Annotation(token, 2497, 2501, right, {'sentence': '0'}, []),
#    Annotation(token, 2502, 2502, ,, {'sentence': '0'}, []),
#    Annotation(token, 2504, 2513, sweetheart, {'sentence': '0'}, []),
#    Annotation(token, 2514, 2514, ., {'sentence': '0'}, []),
#    Annotation(token, 2516, 2519, It's, {'sentence': '0'}, []),
#    Annotation(token, 2521, 2523, all, {'sentence': '0'}, []),
#    Annotation(token, 2525, 2529, right, {'sentence': '0'}, []),
#    Annotation(token, 2530, 2530, ., {'sentence': '0'}, []),
#    Annotation(token, 2532, 2533, Ow, {'sentence': '0'}, []),
#    Annotation(token, 2534, 2534, !, {'sentence': '0'}, []),
#    Annotation(token, 2536, 2539, What, {'sentence': '0'}, []),
#    Annotation(token, 2541, 2548, happened, {'sentence': '0'}, []),
#    Annotation(token, 2549, 2550, ?!, {'sentence': '0'}, []),
#    Annotation(token, 2552, 2552, I, {'sentence': '0'}, []),
#    Annotation(token, 2554, 2558, swear, {'sentence': '0'}, []),
#    Annotation(token, 2560, 2560, I, {'sentence': '0'}, []),
#    Annotation(token, 2562, 2566, don't, {'sentence': '0'}, []),
#    Annotation(token, 2568, 2571, know, {'sentence': '0'}, []),
#    Annotation(token, 2572, 2572, !, {'sentence': '0'}, []),
#    Annotation(token, 2574, 2576, One, {'sentence': '0'}, []),
#    Annotation(token, 2578, 2583, minute, {'sentence': '0'}, []),
#    Annotation(token, 2584, 2584, ,, {'sentence': '0'}, []),
#    Annotation(token, 2586, 2588, the, {'sentence': '0'}, []),
#    Annotation(token, 2590, 2594, glass, {'sentence': '0'}, []),
#    Annotation(token, 2596, 2598, was, {'sentence': '0'}, []),
#    Annotation(token, 2600, 2604, there, {'sentence': '0'}, []),
#    Annotation(token, 2606, 2608, and, {'sentence': '0'}, []),
#    Annotation(token, 2610, 2613, then, {'sentence': '0'}, []),
#    Annotation(token, 2615, 2616, it, {'sentence': '0'}, []),
#    Annotation(token, 2618, 2620, was, {'sentence': '0'}, []),
#    Annotation(token, 2622, 2625, gone, {'sentence': '0'}, []),
#    Annotation(token, 2626, 2626, !, {'sentence': '0'}, []),
#    Annotation(token, 2628, 2629, It, {'sentence': '0'}, []),
#    Annotation(token, 2631, 2633, was, {'sentence': '0'}, []),
#    Annotation(token, 2635, 2638, like, {'sentence': '0'}, []),
#    Annotation(token, 2640, 2644, magic, {'sentence': '0'}, []),
#    Annotation(token, 2645, 2645, !, {'sentence': '0'}, []),
#    Annotation(token, 2647, 2653, There's, {'sentence': '0'}, []),
#    Annotation(token, 2655, 2656, no, {'sentence': '0'}, []),
#    Annotation(token, 2658, 2661, such, {'sentence': '0'}, []),
#    Annotation(token, 2663, 2667, thing, {'sentence': '0'}, []),
#    Annotation(token, 2669, 2670, as, {'sentence': '0'}, []),
#    Annotation(token, 2672, 2676, magic, {'sentence': '0'}, []),
#    Annotation(token, 2677, 2677, !, {'sentence': '0'}, []),
#    Annotation(token, 2679, 2680, Oh, {'sentence': '0'}, []),
#    Annotation(token, 2681, 2681, ,, {'sentence': '0'}, []),
#    Annotation(token, 2683, 2687, Marge, {'sentence': '0'}, []),
#    Annotation(token, 2689, 2690, is, {'sentence': '0'}, []),
#    Annotation(token, 2692, 2694, ill, {'sentence': '0'}, []),
#    Annotation(token, 2695, 2695, !, {'sentence': '0'}, []),
#    Annotation(token, 2697, 2699, Ate, {'sentence': '0'}, []),
#    Annotation(token, 2701, 2701, a, {'sentence': '0'}, []),
#    Annotation(token, 2703, 2707, funny, {'sentence': '0'}, []),
#    Annotation(token, 2709, 2713, whelk, {'sentence': '0'}, []),
#    Annotation(token, 2714, 2714, ., {'sentence': '0'}, []),
#    Annotation(token, 2716, 2718, Dad, {'sentence': '0'}, []),
#    Annotation(token, 2719, 2719, !, {'sentence': '0'}, []),
#    Annotation(token, 2721, 2724, Look, {'sentence': '0'}, []),
#    Annotation(token, 2725, 2725, !, {'sentence': '0'}, []),
#    Annotation(token, 2727, 2733, Harry's, {'sentence': '0'}, []),
#    Annotation(token, 2735, 2737, got, {'sentence': '0'}, []),
#    Annotation(token, 2739, 2739, a, {'sentence': '0'}, []),
#    Annotation(token, 2741, 2746, letter, {'sentence': '0'}, []),
#    Annotation(token, 2747, 2747, !, {'sentence': '0'}, []),
#    Annotation(token, 2749, 2751, Hey, {'sentence': '0'}, []),
#    Annotation(token, 2752, 2752, ,, {'sentence': '0'}, []),
#    Annotation(token, 2754, 2757, give, {'sentence': '0'}, []),
#    Annotation(token, 2759, 2760, it, {'sentence': '0'}, []),
#    Annotation(token, 2762, 2765, back, {'sentence': '0'}, []),
#    Annotation(token, 2766, 2766, !, {'sentence': '0'}, []),
#    Annotation(token, 2768, 2771, It's, {'sentence': '0'}, []),
#    Annotation(token, 2773, 2776, mine, {'sentence': '0'}, []),
#    Annotation(token, 2777, 2777, !, {'sentence': '0'}, []),
#    Annotation(token, 2779, 2783, Yours, {'sentence': '0'}, []),
#    Annotation(token, 2784, 2784, ?, {'sentence': '0'}, []),
#    Annotation(token, 2786, 2790, Who'd, {'sentence': '0'}, []),
#    Annotation(token, 2792, 2793, be, {'sentence': '0'}, []),
#    Annotation(token, 2795, 2801, writing, {'sentence': '0'}, []),
#    Annotation(token, 2803, 2804, to, {'sentence': '0'}, []),
#    Annotation(token, 2806, 2808, you, {'sentence': '0'}, []),
#    Annotation(token, 2809, 2809, ?, {'sentence': '0'}, []),
#    Annotation(token, 2811, 2812, No, {'sentence': '0'}, []),
#    Annotation(token, 2814, 2817, more, {'sentence': '0'}, []),
#    Annotation(token, 2819, 2822, mail, {'sentence': '0'}, []),
#    Annotation(token, 2824, 2830, through, {'sentence': '0'}, []),
#    Annotation(token, 2832, 2835, this, {'sentence': '0'}, []),
#    Annotation(token, 2837, 2845, letterbox, {'sentence': '0'}, []),
#    Annotation(token, 2846, 2846, ., {'sentence': '0'}, []),
#    Annotation(token, 2848, 2851, Have, {'sentence': '0'}, []),
#    Annotation(token, 2853, 2853, a, {'sentence': '0'}, []),
#    Annotation(token, 2855, 2860, lovely, {'sentence': '0'}, []),
#    Annotation(token, 2862, 2864, day, {'sentence': '0'}, []),
#    Annotation(token, 2866, 2867, at, {'sentence': '0'}, []),
#    Annotation(token, 2869, 2871, the, {'sentence': '0'}, []),
#    Annotation(token, 2873, 2878, office, {'sentence': '0'}, []),
#    Annotation(token, 2879, 2879, ,, {'sentence': '0'}, []),
#    Annotation(token, 2881, 2884, dear, {'sentence': '0'}, []),
#    Annotation(token, 2885, 2885, ., {'sentence': '0'}, []),
#    Annotation(token, 2887, 2890, Shoo, {'sentence': '0'}, []),
#    Annotation(token, 2891, 2891, !, {'sentence': '0'}, []),
#    Annotation(token, 2893, 2894, Go, {'sentence': '0'}, []),
#    Annotation(token, 2896, 2897, on, {'sentence': '0'}, []),
#    Annotation(token, 2898, 2898, !, {'sentence': '0'}, []),
#    Annotation(token, 2900, 2903, Fine, {'sentence': '0'}, []),
#    Annotation(token, 2905, 2907, day, {'sentence': '0'}, []),
#    Annotation(token, 2909, 2914, Sunday, {'sentence': '0'}, []),
#    Annotation(token, 2915, 2915, ., {'sentence': '0'}, []),
#    Annotation(token, 2917, 2918, In, {'sentence': '0'}, []),
#    Annotation(token, 2920, 2921, my, {'sentence': '0'}, []),
#    Annotation(token, 2923, 2929, opinion, {'sentence': '0'}, []),
#    Annotation(token, 2930, 2930, ,, {'sentence': '0'}, []),
#    Annotation(token, 2932, 2935, best, {'sentence': '0'}, []),
#    Annotation(token, 2937, 2939, day, {'sentence': '0'}, []),
#    Annotation(token, 2941, 2942, of, {'sentence': '0'}, []),
#    Annotation(token, 2944, 2946, the, {'sentence': '0'}, []),
#    Annotation(token, 2948, 2951, week, {'sentence': '0'}, []),
#    Annotation(token, 2952, 2952, ., {'sentence': '0'}, []),
#    Annotation(token, 2954, 2956, Why, {'sentence': '0'}, []),
# ...
#    Annotation(named_entity, 258, 266, I-pilot, {'B-pilot': '3.0005028E-4', 'I-pilot': '0.99911916', 'I-atco': '5.2066747E-4', 'word': 'something', 'O': '2.8962747E-6', 'sentence': '0', 'B-atco': '5.7224755E-5'}, []),
#    Annotation(named_entity, 268, 269, I-pilot, {'B-pilot': '4.0734466E-4', 'I-pilot': '0.9984883', 'I-atco': '0.0010543625', 'word': 'as', 'O': '4.162965E-6', 'sentence': '0', 'B-atco': '4.580428E-5'}, []),
#    Annotation(named_entity, 271, 279, I-pilot, {'B-pilot': '2.384279E-4', 'I-pilot': '0.99932784', 'I-atco': '4.0593033E-4', 'word': 'important', 'O': '1.9946194E-6', 'sentence': '0', 'B-atco': '2.5802068E-5'}, []),
#    Annotation(named_entity, 281, 282, I-pilot, {'B-pilot': '6.4245507E-4', 'I-pilot': '0.99795514', 'I-atco': '0.0013240856', 'word': 'as', 'O': '6.8773606E-6', 'sentence': '0', 'B-atco': '7.1437935E-5'}, []),
#    Annotation(named_entity, 284, 287, I-pilot, {'B-pilot': '1.4331679E-4', 'I-pilot': '0.9994672', 'I-atco': '3.5416576E-4', 'word': 'this', 'O': '2.700242E-6', 'sentence': '0', 'B-atco': '3.26148E-5'}, []),
#    Annotation(named_entity, 288, 288, I-pilot, {'B-pilot': '0.016691351', 'I-pilot': '0.98241884', 'I-atco': '6.997529E-4', 'word': '?', 'O': '4.848552E-6', 'sentence': '0', 'B-atco': '1.851925E-4'}, []),
#    Annotation(named_entity, 290, 291, I-pilot, {'B-pilot': '0.05025106', 'I-pilot': '0.9490866', 'I-atco': '1.1067195E-4', 'word': 'Ah', 'O': '6.6237044E-6', 'sentence': '0', 'B-atco': '5.45014E-4'}, []),
#    Annotation(named_entity, 292, 292, I-pilot, {'B-pilot': '3.5898702E-4', 'I-pilot': '0.9995709', 'I-atco': '3.2046773E-5', 'word': ',', 'O': '2.1344124E-6', 'sentence': '0', 'B-atco': '3.592952E-5'}, []),
#    Annotation(named_entity, 294, 302, I-pilot, {'B-pilot': '2.606387E-4', 'I-pilot': '0.9996486', 'I-atco': '4.0214243E-5', 'word': 'Professor', 'O': '1.2988709E-6', 'sentence': '0', 'B-atco': '4.9266622E-5'}, []),
#    Annotation(named_entity, 303, 303, I-pilot, {'B-pilot': '3.6188858E-4', 'I-pilot': '0.99956393', 'I-atco': '3.095718E-5', 'word': ',', 'O': '2.3839189E-6', 'sentence': '0', 'B-atco': '4.0867493E-5'}, []),
#    Annotation(named_entity, 305, 305, I-pilot, {'B-pilot': '0.0011135518', 'I-pilot': '0.99867797', 'I-atco': '4.8824262E-5', 'word': 'I', 'O': '1.7163949E-6', 'sentence': '0', 'B-atco': '1.5793719E-4'}, []),
#    Annotation(named_entity, 307, 311, I-pilot, {'B-pilot': '8.304063E-4', 'I-pilot': '0.99891645', 'I-atco': '5.2432708E-5', 'word': 'would', 'O': '2.743038E-6', 'sentence': '0', 'B-atco': '1.9799602E-4'}, []),
#    Annotation(named_entity, 313, 317, I-pilot, {'B-pilot': '2.729837E-4', 'I-pilot': '0.99957734', 'I-atco': '6.75397E-5', 'word': 'trust', 'O': '2.0073292E-6', 'sentence': '0', 'B-atco': '8.012902E-5'}, []),
#    Annotation(named_entity, 319, 324, I-pilot, {'B-pilot': '9.7041356E-4', 'I-pilot': '0.9988391', 'I-atco': '6.888636E-5', 'word': 'Hagrid', 'O': '1.4080211E-6', 'sentence': '0', 'B-atco': '1.20215955E-4'}, []),
#    Annotation(named_entity, 326, 329, I-pilot, {'B-pilot': '0.0029959343', 'I-pilot': '0.9966929', 'I-atco': '1.01403275E-4', 'word': 'with', 'O': '2.929665E-6', 'sentence': '0', 'B-atco': '2.0682598E-4'}, []),
#    Annotation(named_entity, 331, 332, I-pilot, {'B-pilot': '1.0949463E-4', 'I-pilot': '0.9997501', 'I-atco': '8.8437286E-5', 'word': 'my', 'O': '1.048327E-6', 'sentence': '0', 'B-atco': '5.0948685E-5'}, []),
#    Annotation(named_entity, 334, 337, I-pilot, {'B-pilot': '9.471926E-5', 'I-pilot': '0.9997016', 'I-atco': '1.699003E-4', 'word': 'life', 'O': '1.1385835E-6', 'sentence': '0', 'B-atco': '3.2614815E-5'}, []),
#    Annotation(named_entity, 338, 338, I-pilot, {'B-pilot': '4.5370602E-4', 'I-pilot': '0.9994162', 'I-atco': '7.072595E-5', 'word': '.', 'O': '1.897965E-6', 'sentence': '0', 'B-atco': '5.7510693E-5'}, []),
#    Annotation(named_entity, 340, 348, I-pilot, {'B-pilot': '0.006188851', 'I-pilot': '0.9933356', 'I-atco': '9.0384194E-5', 'word': 'Professor', 'O': '2.8661843E-6', 'sentence': '0', 'B-atco': '3.8226615E-4'}, []),
#    Annotation(named_entity, 350, 359, I-pilot, {'B-pilot': '1.3921085E-4', 'I-pilot': '0.99972594', 'I-atco': '7.0859576E-5', 'word': 'Dumbledore', 'O': '9.604861E-7', 'sentence': '0', 'B-atco': '6.301504E-5'}, []),
#    Annotation(named_entity, 360, 360, I-pilot, {'B-pilot': '3.5612445E-4', 'I-pilot': '0.9995023', 'I-atco': '5.550128E-5', 'word': ',', 'O': '1.8506447E-6', 'sentence': '0', 'B-atco': '8.424339E-5'}, []),
#    Annotation(named_entity, 362, 364, I-pilot, {'B-pilot': '1.4716259E-4', 'I-pilot': '0.9996626', 'I-atco': '9.891561E-5', 'word': 'Sir', 'O': '1.2078169E-6', 'sentence': '0', 'B-atco': '9.014431E-5'}, []),
#    Annotation(named_entity, 365, 365, I-pilot, {'B-pilot': '3.5695866E-4', 'I-pilot': '0.9994592', 'I-atco': '9.2902315E-5', 'word': '.', 'O': '1.8886277E-6', 'sentence': '0', 'B-atco': '8.9038665E-5'}, []),
#    Annotation(named_entity, 367, 375, I-pilot, {'B-pilot': '5.2807725E-4', 'I-pilot': '0.9991709', 'I-atco': '1.0030236E-4', 'word': 'Professor', 'O': '1.3487287E-6', 'sentence': '0', 'B-atco': '1.9934462E-4'}, []),
#    Annotation(named_entity, 377, 386, I-pilot, {'B-pilot': '7.991452E-5', 'I-pilot': '0.999739', 'I-atco': '1.2430084E-4', 'word': 'McGonagall', 'O': '8.896013E-7', 'sentence': '0', 'B-atco': '5.58775E-5'}, []),
#    Annotation(named_entity, 387, 387, I-pilot, {'B-pilot': '3.0387205E-4', 'I-pilot': '0.99944794', 'I-atco': '1.7664993E-4', 'word': '.', 'O': '1.3583722E-6', 'sentence': '0', 'B-atco': '7.020406E-5'}, []),
#    Annotation(named_entity, 389, 390, I-pilot, {'B-pilot': '0.002607433', 'I-pilot': '0.9963425', 'I-atco': '1.8309435E-4', 'word': 'No', 'O': '2.5417876E-6', 'sentence': '0', 'B-atco': '8.6443184E-4'}, []),
#    Annotation(named_entity, 392, 399, I-pilot, {'B-pilot': '2.5199258E-4', 'I-pilot': '0.9992364', 'I-atco': '3.0217282E-4', 'word': 'problems', 'O': '1.4133582E-6', 'sentence': '0', 'B-atco': '2.0799521E-4'}, []),
#    Annotation(named_entity, 400, 400, I-pilot, {'B-pilot': '0.0019935516', 'I-pilot': '0.9976911', 'I-atco': '1.599899E-4', 'word': ',', 'O': '2.3072057E-6', 'sentence': '0', 'B-atco': '1.5302999E-4'}, []),
#    Annotation(named_entity, 402, 402, I-pilot, {'B-pilot': '3.7668215E-4', 'I-pilot': '0.99929947', 'I-atco': '1.4706368E-4', 'word': 'I', 'O': '1.1034542E-6', 'sentence': '0', 'B-atco': '1.7565872E-4'}, []),
#    Annotation(named_entity, 404, 408, I-pilot, {'B-pilot': '8.13471E-4', 'I-pilot': '0.9982147', 'I-atco': '2.3968685E-4', 'word': 'trust', 'O': '2.147288E-6', 'sentence': '0', 'B-atco': '7.299531E-4'}, []),
#    Annotation(named_entity, 409, 409, I-pilot, {'B-pilot': '0.0027710195', 'I-pilot': '0.9967766', 'I-atco': '2.3762695E-4', 'word': ',', 'O': '2.7434303E-6', 'sentence': '0', 'B-atco': '2.1200148E-4'}, []),
#    Annotation(named_entity, 411, 416, I-pilot, {'B-pilot': '5.809398E-4', 'I-pilot': '0.99899334', 'I-atco': '1.9173024E-4', 'word': 'Hagrid', 'O': '1.1968361E-6', 'sentence': '0', 'B-atco': '2.3278115E-4'}, []),
#    Annotation(named_entity, 417, 417, I-pilot, {'B-pilot': '4.2851115E-4', 'I-pilot': '0.9990212', 'I-atco': '2.2772845E-4', 'word': '?', 'O': '1.2987008E-6', 'sentence': '0', 'B-atco': '3.212628E-4'}, []),
#    Annotation(named_entity, 419, 420, I-pilot, {'B-pilot': '0.006383553', 'I-pilot': '0.9878862', 'I-atco': '3.4051426E-4', 'word': 'No', 'O': '2.9696378E-6', 'sentence': '0', 'B-atco': '0.0053867428'}, []),
#    Annotation(named_entity, 421, 421, I-pilot, {'B-pilot': '3.2290578E-4', 'I-pilot': '0.99893284', 'I-atco': '4.5035922E-4', 'word': ',', 'O': '1.2336743E-6', 'sentence': '0', 'B-atco': '2.9263925E-4'}, []),
#    Annotation(named_entity, 423, 425, I-pilot, {'B-pilot': '1.383477E-4', 'I-pilot': '0.9987425', 'I-atco': '8.3593244E-4', 'word': 'Sir', 'O': '1.0833954E-6', 'sentence': '0', 'B-atco': '2.8209397E-4'}, []),
#    Annotation(named_entity, 426, 426, I-pilot, {'B-pilot': '3.2891904E-4', 'I-pilot': '0.9978013', 'I-atco': '0.0014835595', 'word': '.', 'O': '1.4985491E-6', 'sentence': '0', 'B-atco': '3.8472592E-4'}, []),
#    Annotation(named_entity, 428, 433, I-pilot, {'B-pilot': '0.0010264218', 'I-pilot': '0.9973195', 'I-atco': '8.3863136E-4', 'word': 'Little', 'O': '1.2520877E-6', 'sentence': '0', 'B-atco': '8.141706E-4'}, []),
#    Annotation(named_entity, 435, 438, I-pilot, {'B-pilot': '0.002716344', 'I-pilot': '0.98789114', 'I-atco': '0.001596213', 'word': 'tyke', 'O': '2.6964972E-6', 'sentence': '0', 'B-atco': '0.0077936337'}, []),
#    Annotation(named_entity, 440, 443, I-pilot, {'B-pilot': '3.12308E-4', 'I-pilot': '0.9967978', 'I-atco': '0.001915411', 'word': 'fell', 'O': '1.8998941E-6', 'sentence': '0', 'B-atco': '9.725933E-4'}, []),
#    Annotation(named_entity, 445, 450, I-pilot, {'B-pilot': '2.699914E-4', 'I-pilot': '0.9915094', 'I-atco': '0.0071989023', 'word': 'asleep', 'O': '2.3709913E-6', 'sentence': '0', 'B-atco': '0.0010193641'}, []),
#    Annotation(named_entity, 452, 455, I-pilot, {'B-pilot': '6.069356E-4', 'I-pilot': '0.99339134', 'I-atco': '0.005221755', 'word': 'just', 'O': '2.2340869E-6', 'sentence': '0', 'B-atco': '7.777638E-4'}, []),
#    Annotation(named_entity, 457, 458, I-pilot, {'B-pilot': '3.313678E-4', 'I-pilot': '0.9904057', 'I-atco': '0.0089915125', 'word': 'as', 'O': '4.2895317E-6', 'sentence': '0', 'B-atco': '2.671311E-4'}, []),
#    Annotation(named_entity, 460, 461, I-pilot, {'B-pilot': '3.3902202E-4', 'I-pilot': '0.99820685', 'I-atco': '0.0011933467', 'word': 'we', 'O': '2.6635325E-6', 'sentence': '0', 'B-atco': '2.5810368E-4'}, []),
#    Annotation(named_entity, 463, 466, I-pilot, {'B-pilot': '3.6246024E-4', 'I-pilot': '0.9980869', 'I-atco': '0.0013726942', 'word': 'were', 'O': '4.145424E-6', 'sentence': '0', 'B-atco': '1.7378488E-4'}, []),
#    Annotation(named_entity, 468, 473, I-pilot, {'B-pilot': '2.1191487E-4', 'I-pilot': '0.9992554', 'I-atco': '4.8846274E-4', 'word': 'flying', 'O': '2.293119E-6', 'sentence': '0', 'B-atco': '4.189874E-5'}, []),
#    Annotation(named_entity, 475, 478, I-pilot, {'B-pilot': '1.9736543E-4', 'I-pilot': '0.99800223', 'I-atco': '0.0017264788', 'word': 'over', 'O': '3.4109476E-6', 'sentence': '0', 'B-atco': '7.0523995E-5'}, []),
#    Annotation(named_entity, 480, 486, I-pilot, {'B-pilot': '9.2895253E-4', 'I-pilot': '0.99186057', 'I-atco': '0.0011150915', 'word': 'Bristol', 'O': '3.2535638E-6', 'sentence': '0', 'B-atco': '0.006092124'}, []),
#    Annotation(named_entity, 487, 487, I-pilot, {'B-pilot': '0.0042783855', 'I-pilot': '0.96834564', 'I-atco': '0.015874727', 'word': '.', 'O': '6.8054305E-6', 'sentence': '0', 'B-atco': '0.011494434'}, []),
#    Annotation(named_entity, 489, 495, B-atco, {'B-pilot': '0.062078487', 'I-pilot': '0.26188084', 'I-atco': '0.0065782215', 'word': 'Heh.Try', 'O': '1.7829161E-5', 'sentence': '0', 'B-atco': '0.6694446'}, []),
#    Annotation(named_entity, 497, 499, B-atco, {'B-pilot': '0.0060534817', 'I-pilot': '0.0351196', 'I-atco': '0.03775658', 'word': 'not', 'O': '3.7556507E-5', 'sentence': '0', 'B-atco': '0.9210328'}, []),
#    Annotation(named_entity, 501, 502, I-pilot, {'B-pilot': '0.0062731495', 'I-pilot': '0.5637967', 'I-atco': '0.38717774', 'word': 'to', 'O': '3.0957388E-5', 'sentence': '0', 'B-atco': '0.04272144'}, []),
#    Annotation(named_entity, 504, 507, I-atco, {'B-pilot': '0.0023612422', 'I-pilot': '0.26239967', 'I-atco': '0.7124406', 'word': 'wake', 'O': '2.2554455E-5', 'sentence': '0', 'B-atco': '0.022775928'}, []),
#    Annotation(named_entity, 509, 511, I-pilot, {'B-pilot': '0.0039659617', 'I-pilot': '0.5397836', 'I-atco': '0.45432007', 'word': 'him', 'O': '2.5958461E-5', 'sentence': '0', 'B-atco': '0.0019043993'}, []),
#    Annotation(named_entity, 512, 512, I-pilot, {'B-pilot': '0.020466007', 'I-pilot': '0.9357141', 'I-atco': '0.037509587', 'word': '.', 'O': '9.94284E-6', 'sentence': '0', 'B-atco': '0.0063003376'}, []),
#    Annotation(named_entity, 514, 518, B-atco, {'B-pilot': '0.24247631', 'I-pilot': '0.16573574', 'I-atco': '0.0063566403', 'word': 'There', 'O': '3.322222E-5', 'sentence': '0', 'B-atco': '0.5853981'}, []),
#    Annotation(named_entity, 520, 522, I-pilot, {'B-pilot': '1.8892121E-4', 'I-pilot': '0.97805023', 'I-atco': '0.021363776', 'word': 'you', 'O': '2.9651985E-6', 'sentence': '0', 'B-atco': '3.94134E-4'}, []),
#    Annotation(named_entity, 524, 525, I-pilot, {'B-pilot': '7.6085795E-4', 'I-pilot': '0.9605481', 'I-atco': '0.03732699', 'word': 'go', 'O': '6.375522E-6', 'sentence': '0', 'B-atco': '0.0013576916'}, []),
#    Annotation(named_entity, 526, 526, I-pilot, {'B-pilot': '0.0021992077', 'I-pilot': '0.9893445', 'I-atco': '0.007835066', 'word': '.', 'O': '2.7506435E-6', 'sentence': '0', 'B-atco': '6.184774E-4'}, []),
#    Annotation(named_entity, 528, 532, I-pilot, {'B-pilot': '0.18911992', 'I-pilot': '0.5320915', 'I-atco': '0.0037146274', 'word': 'Albus', 'O': '1.7501303E-5', 'sentence': '0', 'B-atco': '0.27505645'}, []),
#    Annotation(named_entity, 533, 533, I-pilot, {'B-pilot': '0.01337088', 'I-pilot': '0.8155125', 'I-atco': '0.08002533', 'word': ',', 'O': '2.1265023E-5', 'sentence': '0', 'B-atco': '0.09107003'}, []),
#    Annotation(named_entity, 535, 536, I-pilot, {'B-pilot': '0.012919829', 'I-pilot': '0.48549345', 'I-atco': '0.36408284', 'word': 'do', 'O': '2.061061E-5', 'sentence': '0', 'B-atco': '0.13748327'}, []),
#    Annotation(named_entity, 538, 540, I-pilot, {'B-pilot': '6.7151885E-4', 'I-pilot': '0.6241517', 'I-atco': '0.373026', 'word': 'you', 'O': '6.4535666E-6', 'sentence': '0', 'B-atco': '0.0021443092'}, []),
#    Annotation(named_entity, 542, 547, I-atco, {'B-pilot': '9.451905E-4', 'I-pilot': '0.17614144', 'I-atco': '0.821102', 'word': 'really', 'O': '3.0732472E-6', 'sentence': '0', 'B-atco': '0.0018082462'}, []),
#    Annotation(named_entity, 549, 553, I-atco, {'B-pilot': '0.0011804601', 'I-pilot': '0.07841605', 'I-atco': '0.9178976', 'word': 'think', 'O': '3.658868E-6', 'sentence': '0', 'B-atco': '0.0025022412'}, []),
#    Annotation(named_entity, 555, 558, I-atco, {'B-pilot': '0.002435884', 'I-pilot': '0.054837372', 'I-atco': '0.93950164', 'word': "it's", 'O': '2.9261937E-6', 'sentence': '0', 'B-atco': '0.00322215'}, []),
#    Annotation(named_entity, 560, 563, I-atco, {'B-pilot': '5.2623363E-4', 'I-pilot': '0.025860583', 'I-atco': '0.9730073', 'word': 'safe', 'O': '1.6455481E-6', 'sentence': '0', 'B-atco': '6.0420105E-4'}, []),
#    Annotation(named_entity, 564, 564, I-pilot, {'B-pilot': '3.8406736E-4', 'I-pilot': '0.8639541', 'I-atco': '0.13451846', 'word': ',', 'O': '4.080695E-6', 'sentence': '0', 'B-atco': '0.0011392912'}, []),
#    Annotation(named_entity, 566, 572, B-pilot, {'B-pilot': '0.83839065', 'I-pilot': '0.15756068', 'I-atco': '0.0023081412', 'word': 'leaving', 'O': '2.4343728E-5', 'sentence': '0', 'B-atco': '0.0017162081'}, [])],
#   'ner_span': [Annotation(chunk, 0, 41, I should have known that you would be here, {'entity': 'pilot', 'sentence': '0', 'chunk': '0', 'confidence': '0.8901479'}, []),
#    Annotation(chunk, 42, 487, , Professor McGonagall. Good evening, Professor Dumbledore. Are the rumours true Albus? I'm afraid so, Professor. The good, and the bad. And the boy? Hagrid is bringing him. Do you think it wise to trust Hagrid with something as important as this? Ah, Professor, I would trust Hagrid with my life. Professor Dumbledore, Sir. Professor McGonagall. No problems, I trust, Hagrid? No, Sir. Little tyke fell asleep just as we were flying over Bristol., {'entity': 'pilot', 'sentence': '0', 'chunk': '1', 'confidence': '0.98205596'}, []),
#    Annotation(chunk, 489, 495, Heh.Try, {'entity': 'atco', 'sentence': '0', 'chunk': '2', 'confidence': '0.6694446'}, []),
#    Annotation(chunk, 497, 512, not to wake him., {'entity': 'atco', 'sentence': '0', 'chunk': '3', 'confidence': '0.7345535'}, []),
#    Annotation(chunk, 514, 564, There you go. Albus, do you really think it's safe,, {'entity': 'atco', 'sentence': '0', 'chunk': '4', 'confidence': '0.8066195'}, []),
#    Annotation(chunk, 566, 572, leaving, {'entity': 'pilot', 'sentence': '0', 'chunk': '5', 'confidence': '0.83839065'}, [])]}]

# %%
model = pipeline.fit(data)
result = model.transform(data)

result.select(
    F.explode(F.arrays_zip(result.ner_span.result, result.ner_span.metadata)).alias(
        "cols"
    )
).select(F.expr("cols['0']"), F.expr("cols['1'].entity")).show()

# Convert to LightPipeline Model
# lmodel = LightPipeline(model)
# lmodel.fullAnnotate(dialogue)
# Out:
# +--------------------+--------------+
# |              cols.0|cols.1[entity]|
# +--------------------+--------------+
# |I should have kno...|          atco|
# |                   ,|         pilot|
# |Professor McGonag...|         pilot|
# |Good evening, Pro...|         pilot|
# |Are the rumours t...|         pilot|
# |I'm afraid so, Pr...|         pilot|
# |The good, and the...|         pilot|
# |        And the boy?|         pilot|
# |Hagrid is bringin...|         pilot|
# |Do you think it w...|          atco|
# |Hagrid with somet...|         pilot|
# |Ah, Professor, I ...|         pilot|
# |Professor Dumbled...|         pilot|
# |No problems, I tr...|         pilot|
# |No, Sir. Little t...|         pilot|
# |    not to wake him.|          atco|
# |       There you go.|         pilot|
# |Albus, do you rea...|         pilot|
# |I've watched them...|         pilot|
# |The only family h...|          atco|
# +--------------------+--------------+
# only showing top 20 rows

# %% [raw]
# # Import the required modules and classes
# from sparknlp.base import DocumentAssembler, Pipeline, LightPipeline
# from sparknlp.annotator import (
#     Tokenizer,
#     WordEmbeddingsModel,
#     NerDLModel,
#     NerConverter
# )
# import pyspark.sql.functions as F
#
# # Step 1: Transforms raw texts to `document` annotation
# documentAssembler = DocumentAssembler()\
#     .setInputCol("text")\
#     .setOutputCol("document")
#
# # Step 2: Tokenization
# tokenizer = Tokenizer() \
#     .setInputCols(["document"]) \
#     .setOutputCol("token")
#
# # Step 3: Get the embeddings using glove_100d
# embeddings = WordEmbeddingsModel.pretrained('glove_100d').\
#                   setInputCols(["document", 'token']).\
#                   setOutputCol("embeddings")
#
# # Step 4: Use the ner_dl model
# public_ner = NerDLModel.pretrained('ner_dl', 'en') \
#           .setInputCols(["document", "token", "embeddings"]) \
#           .setOutputCol("ner")
#
# # Step 5: Convert to user-friendly NER
# ner_converter = NerConverter() \
#                 .setInputCols(["document", "token", "ner"]) \
#                   .setOutputCol("entities")
#
# # Define the pipeline
# nlpPipeline = Pipeline(stages=[ documentAssembler,
#                                  tokenizer,
#                                  embeddings,
#                                  public_ner,
#                                  ner_converter
#                                  ])
#
# # Create the dataframe
# empty_df = spark.createDataFrame([['']]).toDF("text")
#
# # Fit the dataframe to the pipeline to get the model
# pipelineModel = nlpPipeline.fit(empty_df)
#
# # Convert to LightPipeline Model
# lmodel = LightPipeline(pipelineModel)
#
# # Full annotate the light model to get predictions
# cpres = lmodel.fullAnnotate(data)
